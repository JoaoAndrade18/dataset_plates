# %%
print("Test!")
# Out:
# Test!

# %%
# !pip install fast-plate-ocr[train,onnx]
# !pip install "tensorflow[and-cuda]==2.20.0"
# Out:
# Requirement already satisfied: fast-plate-ocr[onnx,train] in c:\users\batis\documents\projeto-wisecontrol\.venv_wisecontrol\lib\site-packages (1.0.2)
# Requirement already satisfied: numpy>=1.20 in c:\users\batis\documents\projeto-wisecontrol\.venv_wisecontrol\lib\site-packages (from fast-plate-ocr[onnx,train]) (2.2.6)
# Requirement already satisfied: opencv-python-headless in c:\users\batis\documents\projeto-wisecontrol\.venv_wisecontrol\lib\site-packages (from fast-plate-ocr[onnx,train]) (4.12.0.88)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\batis\documents\projeto-wisecontrol\.venv_wisecontrol\lib\site-packages (from fast-plate-ocr[onnx,train]) (6.0.3)
# Requirement already satisfied: rich in c:\users\batis\documents\projeto-wisecontrol\.venv_wisecontrol\lib\site-packages (from fast-plate-ocr[onnx,train]) (14.2.0)
# Requirement already satisfied: tqdm in c:\users\batis\documents\projeto-wisecontrol\.venv_wisecontrol\lib\site-packages (from fast-plate-ocr[onnx,train]) (4.67.1)
# Requirement already satisfied: onnxruntime in c:\users\batis\documents\projeto-wisecontrol\.venv_wisecontrol\lib\site-packages (from fast-plate-ocr[onnx,train]) (1.23.2)
# Requirement already satisfied: albumentations in c:\users\batis\documents\projeto-wisecontrol\.venv_wisecontrol\lib\site-packages (from fast-plate-ocr[onnx,train]) (2.0.8)
# Requirement already satisfied: click in c:\users\batis\documents\projeto-wisecontrol\.venv_wisecontrol\lib\site-packages (from fast-plate-ocr[onnx,train]) (8.3.0)
# Requirement already satisfied: coremltools in c:\users\batis\documents\projeto-wisecontrol\.venv_wisecontrol\lib\site-packages (from fast-plate-ocr[onnx,train]) (9.0)
# Requirement already satisfied: keras<4,>=3.10.0 in c:\users\batis\documents\projeto-wisecontrol\.venv_wisecontrol\lib\site-packages (from fast-plate-ocr[onnx,train]) (3.12.0)
# Requirement already satisfied: matplotlib in c:\users\batis\documents\projeto-wisecontrol\.venv_wisecontrol\lib\site-packages (from fast-plate-ocr[onnx,train]) (3.10.7)
# Requirement already satisfied: onnxslim>=0.1.56 in c:\users\batis\documents\projeto-wisecontrol\.venv_wisecontrol\lib\site-packages (from fast-plate-ocr[onnx,train]) (0.1.74)
# Requirement already satisfied: pandas in c:\users\batis\documents\projeto-wisecontrol\.venv_wisecontrol\lib\site-packages (from fast-plate-ocr[onnx,train]) (2.3.3)
# Requirement already satisfied: pydantic<3,>=2.5.2 in c:\users\batis\documents\projeto-wisecontrol\.venv_wisecontrol\lib\site-packages (from fast-plate-ocr[onnx,train]) (2.12.4)
# Requirement already satisfied: scikit-learn in c:\users\batis\documents\projeto-wisecontrol\.venv_wisecontrol\lib\site-packages (from fast-plate-ocr[onnx,train]) (1.7.2)
# Requirement already satisfied: tensorboard in c:\users\batis\documents\projeto-wisecontrol\.venv_wisecontrol\lib\site-packages (from fast-plate-ocr[onnx,train]) (2.20.0)
# Requirement already satisfied: tensorflow in c:\users\batis\documents\projeto-wisecontrol\.venv_wisecontrol\lib\site-packages (from fast-plate-ocr[onnx,train]) (2.20.0)
# Requirement already satisfied: tf2onnx in c:\users\batis\documents\projeto-wisecontrol\.venv_wisecontrol\lib\site-packages (from fast-plate-ocr[onnx,train]) (1.8.4)
# Requirement already satisfied: absl-py in c:\users\batis\documents\projeto-wisecontrol\.venv_wisecontrol\lib\site-packages (from keras<4,>=3.10.0->fast-plate-ocr[onnx,train]) (2.3.1)
# Requirement already satisfied: namex in c:\users\batis\documents\projeto-wisecontrol\.venv_wisecontrol\lib\site-packages (from keras<4,>=3.10.0->fast-plate-ocr[onnx,train]) (0.1.0)
# Requirement already satisfied: h5py in c:\users\batis\documents\projeto-wisecontrol\.venv_wisecontrol\lib\site-packages (from keras<4,>=3.10.0->fast-plate-ocr[onnx,train]) (3.15.1)
# Requirement already satisfied: optree in c:\users\batis\documents\projeto-wisecontrol\.venv_wisecontrol\lib\site-packages (from keras<4,>=3.10.0->fast-plate-ocr[onnx,train]) (0.17.0)
# Requirement already satisfied: ml-dtypes in c:\users\batis\documents\projeto-wisecontrol\.venv_wisecontrol\lib\site-packages (from keras<4,>=3.10.0->fast-plate-ocr[onnx,train]) (0.5.3)
# Requirement already satisfied: packaging in c:\users\batis\documents\projeto-wisecontrol\.venv_wisecontrol\lib\site-packages (from keras<4,>=3.10.0->fast-plate-ocr[onnx,train]) (25.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\batis\documents\projeto-wisecontrol\.venv_wisecontrol\lib\site-packages (from pydantic<3,>=2.5.2->fast-plate-ocr[onnx,train]) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\users\batis\documents\projeto-wisecontrol\.venv_wisecontrol\lib\site-packages (from pydantic<3,>=2.5.2->fast-plate-ocr[onnx,train]) (2.41.5)
# Requirement already satisfied: typing-extensions>=4.14.1 in c:\users\batis\documents\projeto-wisecontrol\.venv_wisecontrol\lib\site-packages (from pydantic<3,>=2.5.2->fast-plate-ocr[onnx,train]) (4.15.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\batis\documents\projeto-wisecontrol\.venv_wisecontrol\lib\site-packages (from pydantic<3,>=2.5.2->fast-plate-ocr[onnx,train]) (0.4.2)
# Requirement already satisfied: onnx in c:\users\batis\documents\projeto-wisecontrol\.venv_wisecontrol\lib\site-packages (from onnxslim>=0.1.56->fast-plate-ocr[onnx,train]) (1.19.1)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\batis\documents\projeto-wisecontrol\.venv_wisecontrol\lib\site-packages (from onnxslim>=0.1.56->fast-plate-ocr[onnx,train]) (1.14.0)
# Requirement already satisfied: colorama in c:\users\batis\documents\projeto-wisecontrol\.venv_wisecontrol\lib\site-packages (from onnxslim>=0.1.56->fast-plate-ocr[onnx,train]) (0.4.6)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\batis\documents\projeto-wisecontrol\.venv_wisecontrol\lib\site-packages (from sympy>=1.13.3->onnxslim>=0.1.56->fast-plate-ocr[onnx,train]) (1.3.0)
# Requirement already satisfied: scipy>=1.10.0 in c:\users\batis\documents\projeto-wisecontrol\.venv_wisecontrol\lib\site-packages (from albumentations->fast-plate-ocr[onnx,train]) (1.16.3)
# Requirement already satisfied: albucore==0.0.24 in c:\users\batis\documents\projeto-wisecontrol\.venv_wisecontrol\lib\site-packages (from albumentations->fast-plate-ocr[onnx,train]) (0.0.24)
# Requirement already satisfied: stringzilla>=3.10.4 in c:\users\batis\documents\projeto-wisecontrol\.venv_wisecontrol\lib\site-packages (from albucore==0.0.24->albumentations->fast-plate-ocr[onnx,train]) (4.2.3)
# Requirement already satisfied: simsimd>=5.9.2 in c:\users\batis\documents\projeto-wisecontrol\.venv_wisecontrol\lib\site-packages (from albucore==0.0.24->albumentations->fast-plate-ocr[onnx,train]) (6.5.3)
# Requirement already satisfied: protobuf>=3.1.0 in c:\users\batis\documents\projeto-wisecontrol\.venv_wisecontrol\lib\site-packages (from coremltools->fast-plate-ocr[onnx,train]) (6.33.0)
# Requirement already satisfied: attrs>=21.3.0 in c:\users\batis\documents\projeto-wisecontrol\.venv_wisecontrol\lib\site-packages (from coremltools->fast-plate-ocr[onnx,train]) (25.4.0)
# Requirement already satisfied: cattrs in c:\users\batis\documents\projeto-wisecontrol\.venv_wisecontrol\lib\site-packages (from coremltools->fast-plate-ocr[onnx,train]) (25.3.0)
# Requirement already satisfied: pyaml in c:\users\batis\documents\projeto-wisecontrol\.venv_wisecontrol\lib\site-packages (from coremltools->fast-plate-ocr[onnx,train]) (25.7.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\batis\documents\projeto-wisecontrol\.venv_wisecontrol\lib\site-packages (from matplotlib->fast-plate-ocr[onnx,train]) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\batis\documents\projeto-wisecontrol\.venv_wisecontrol\lib\site-packages (from matplotlib->fast-plate-ocr[onnx,train]) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\batis\documents\projeto-wisecontrol\.venv_wisecontrol\lib\site-packages (from matplotlib->fast-plate-ocr[onnx,train]) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\batis\documents\projeto-wisecontrol\.venv_wisecontrol\lib\site-packages (from matplotlib->fast-plate-ocr[onnx,train]) (1.4.9)
# Requirement already satisfied: pillow>=8 in c:\users\batis\documents\projeto-wisecontrol\.venv_wisecontrol\lib\site-packages (from matplotlib->fast-plate-ocr[onnx,train]) (12.0.0)
# Requirement already satisfied: pyparsing>=3 in c:\users\batis\documents\projeto-wisecontrol\.venv_wisecontrol\lib\site-packages (from matplotlib->fast-plate-ocr[onnx,train]) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\batis\documents\projeto-wisecontrol\.venv_wisecontrol\lib\site-packages (from matplotlib->fast-plate-ocr[onnx,train]) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\batis\documents\projeto-wisecontrol\.venv_wisecontrol\lib\site-packages (from python-dateutil>=2.7->matplotlib->fast-plate-ocr[onnx,train]) (1.17.0)
# Requirement already satisfied: coloredlogs in c:\users\batis\documents\projeto-wisecontrol\.venv_wisecontrol\lib\site-packages (from onnxruntime->fast-plate-ocr[onnx,train]) (15.0.1)
# Requirement already satisfied: flatbuffers in c:\users\batis\documents\projeto-wisecontrol\.venv_wisecontrol\lib\site-packages (from onnxruntime->fast-plate-ocr[onnx,train]) (25.9.23)
# Requirement already satisfied: humanfriendly>=9.1 in c:\users\batis\documents\projeto-wisecontrol\.venv_wisecontrol\lib\site-packages (from coloredlogs->onnxruntime->fast-plate-ocr[onnx,train]) (10.0)
# Requirement already satisfied: pyreadline3 in c:\users\batis\documents\projeto-wisecontrol\.venv_wisecontrol\lib\site-packages (from humanfriendly>=9.1->coloredlogs->onnxruntime->fast-plate-ocr[onnx,train]) (3.5.4)
# Requirement already satisfied: pytz>=2020.1 in c:\users\batis\documents\projeto-wisecontrol\.venv_wisecontrol\lib\site-packages (from pandas->fast-plate-ocr[onnx,train]) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\batis\documents\projeto-wisecontrol\.venv_wisecontrol\lib\site-packages (from pandas->fast-plate-ocr[onnx,train]) (2025.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\batis\documents\projeto-wisecontrol\.venv_wisecontrol\lib\site-packages (from rich->fast-plate-ocr[onnx,train]) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\batis\documents\projeto-wisecontrol\.venv_wisecontrol\lib\site-packages (from rich->fast-plate-ocr[onnx,train]) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in c:\users\batis\documents\projeto-wisecontrol\.venv_wisecontrol\lib\site-packages (from markdown-it-py>=2.2.0->rich->fast-plate-ocr[onnx,train]) (0.1.2)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\batis\documents\projeto-wisecontrol\.venv_wisecontrol\lib\site-packages (from scikit-learn->fast-plate-ocr[onnx,train]) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\batis\documents\projeto-wisecontrol\.venv_wisecontrol\lib\site-packages (from scikit-learn->fast-plate-ocr[onnx,train]) (3.6.0)
# Requirement already satisfied: grpcio>=1.48.2 in c:\users\batis\documents\projeto-wisecontrol\.venv_wisecontrol\lib\site-packages (from tensorboard->fast-plate-ocr[onnx,train]) (1.76.0)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\batis\documents\projeto-wisecontrol\.venv_wisecontrol\lib\site-packages (from tensorboard->fast-plate-ocr[onnx,train]) (3.10)
# Requirement already satisfied: setuptools>=41.0.0 in c:\users\batis\documents\projeto-wisecontrol\.venv_wisecontrol\lib\site-packages (from tensorboard->fast-plate-ocr[onnx,train]) (80.9.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\batis\documents\projeto-wisecontrol\.venv_wisecontrol\lib\site-packages (from tensorboard->fast-plate-ocr[onnx,train]) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\batis\documents\projeto-wisecontrol\.venv_wisecontrol\lib\site-packages (from tensorboard->fast-plate-ocr[onnx,train]) (3.1.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\batis\documents\projeto-wisecontrol\.venv_wisecontrol\lib\site-packages (from werkzeug>=1.0.1->tensorboard->fast-plate-ocr[onnx,train]) (3.0.3)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\batis\documents\projeto-wisecontrol\.venv_wisecontrol\lib\site-packages (from tensorflow->fast-plate-ocr[onnx,train]) (1.6.3)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\batis\documents\projeto-wisecontrol\.venv_wisecontrol\lib\site-packages (from tensorflow->fast-plate-ocr[onnx,train]) (0.6.0)
# Requirement already satisfied: google_pasta>=0.1.1 in c:\users\batis\documents\projeto-wisecontrol\.venv_wisecontrol\lib\site-packages (from tensorflow->fast-plate-ocr[onnx,train]) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\batis\documents\projeto-wisecontrol\.venv_wisecontrol\lib\site-packages (from tensorflow->fast-plate-ocr[onnx,train]) (18.1.1)
# Requirement already satisfied: opt_einsum>=2.3.2 in c:\users\batis\documents\projeto-wisecontrol\.venv_wisecontrol\lib\site-packages (from tensorflow->fast-plate-ocr[onnx,train]) (3.4.0)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\batis\documents\projeto-wisecontrol\.venv_wisecontrol\lib\site-packages (from tensorflow->fast-plate-ocr[onnx,train]) (2.32.5)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\batis\documents\projeto-wisecontrol\.venv_wisecontrol\lib\site-packages (from tensorflow->fast-plate-ocr[onnx,train]) (3.2.0)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\batis\documents\projeto-wisecontrol\.venv_wisecontrol\lib\site-packages (from tensorflow->fast-plate-ocr[onnx,train]) (2.0.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\batis\documents\projeto-wisecontrol\.venv_wisecontrol\lib\site-packages (from requests<3,>=2.21.0->tensorflow->fast-plate-ocr[onnx,train]) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\batis\documents\projeto-wisecontrol\.venv_wisecontrol\lib\site-packages (from requests<3,>=2.21.0->tensorflow->fast-plate-ocr[onnx,train]) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\batis\documents\projeto-wisecontrol\.venv_wisecontrol\lib\site-packages (from requests<3,>=2.21.0->tensorflow->fast-plate-ocr[onnx,train]) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\batis\documents\projeto-wisecontrol\.venv_wisecontrol\lib\site-packages (from requests<3,>=2.21.0->tensorflow->fast-plate-ocr[onnx,train]) (2025.11.12)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\batis\documents\projeto-wisecontrol\.venv_wisecontrol\lib\site-packages (from astunparse>=1.6.0->tensorflow->fast-plate-ocr[onnx,train]) (0.45.1)
# ERROR: Invalid requirement: 'tensorflow[and-cuda]==latest': Expected end or semicolon (after name and no valid version specifier)
#     tensorflow[and-cuda]==latest
#                         ^

# %%
# Disable TF disable all debugging logs
# %env TF_CPP_MIN_LOG_LEVEL=3
# Use TensorFlow as Keras backned (JAX and PyTorch are also supported!)
# %env KERAS_BACKEND=tensorflow
# Out:
# env: TF_CPP_MIN_LOG_LEVEL=3
# env: KERAS_BACKEND=tensorflow

# %%
# Check the train annotations
# !fast-plate-ocr validate-dataset \
  --annotations-file train.csv \
  --plate-config-file cct_s_v1_global_plate_config.yaml
# Out:
# Traceback (most recent call last):
#   File "C:\Users\batis\Documents\PROJETO-WISECONTROL\.venv_wisecontrol\Lib\site-packages\rich\live.py", line 133, in start
#     self.refresh()
#   File "C:\Users\batis\Documents\PROJETO-WISECONTROL\.venv_wisecontrol\Lib\site-packages\rich\live.py", line 266, in refresh
#     with self.console:
#   File "C:\Users\batis\Documents\PROJETO-WISECONTROL\.venv_wisecontrol\Lib\site-packages\rich\console.py", line 870, in __exit__
#     self._exit_buffer()
#   File "C:\Users\batis\Documents\PROJETO-WISECONTROL\.venv_wisecontrol\Lib\site-packages\rich\console.py", line 826, in _exit_buffer
#     self._check_buffer()
#   File "C:\Users\batis\Documents\PROJETO-WISECONTROL\.venv_wisecontrol\Lib\site-packages\rich\console.py", line 2038, in _check_buffer
#     self._write_buffer()
#   File "C:\Users\batis\Documents\PROJETO-WISECONTROL\.venv_wisecontrol\Lib\site-packages\rich\console.py", line 2074, in _write_buffer
#     legacy_windows_render(buffer, LegacyWindowsTerm(self.file))
#   File "C:\Users\batis\Documents\PROJETO-WISECONTROL\.venv_wisecontrol\Lib\site-packages\rich\_windows_renderer.py", line 17, in legacy_windows_render
#     term.write_styled(text, style)
#   File "C:\Users\batis\Documents\PROJETO-WISECONTROL\.venv_wisecontrol\Lib\site-packages\rich\_win32_console.py", line 441, in write_styled
#     self.write_text(text)
#   File "C:\Users\batis\Documents\PROJETO-WISECONTROL\.venv_wisecontrol\Lib\site-packages\rich\_win32_console.py", line 402, in write_text
#     self.write(text)
#   File "C:\Users\batis\AppData\Local\Programs\Python\Python312\Lib\encodings\cp1252.py", line 19, in encode
#     return codecs.charmap_encode(input,self.errors,encoding_table)[0]
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# UnicodeEncodeError: 'charmap' codec can't encode character '\u280b' in position 0: character maps to <undefined>
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "C:\Users\batis\Documents\PROJETO-WISECONTROL\.venv_wisecontrol\Scripts\fast-plate-ocr.exe\__main__.py", line 6, in <module>
#   File "C:\Users\batis\Documents\PROJETO-WISECONTROL\.venv_wisecontrol\Lib\site-packages\click\core.py", line 1462, in __call__
#     return self.main(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\batis\Documents\PROJETO-WISECONTROL\.venv_wisecontrol\Lib\site-packages\click\core.py", line 1383, in main
#     rv = self.invoke(ctx)
#          ^^^^^^^^^^^^^^^^
#   File "C:\Users\batis\Documents\PROJETO-WISECONTROL\.venv_wisecontrol\Lib\site-packages\click\core.py", line 1850, in invoke
#     return _process_result(sub_ctx.command.invoke(sub_ctx))
#                            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\batis\Documents\PROJETO-WISECONTROL\.venv_wisecontrol\Lib\site-packages\click\core.py", line 1246, in invoke
#     return ctx.invoke(self.callback, **ctx.params)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\batis\Documents\PROJETO-WISECONTROL\.venv_wisecontrol\Lib\site-packages\click\core.py", line 814, in invoke
#     return callback(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\batis\Documents\PROJETO-WISECONTROL\.venv_wisecontrol\Lib\site-packages\fast_plate_ocr\cli\validate_dataset.py", line 208, in validate_dataset
#     errors, warnings, cleaned = _validate_dataset(df_annots, cfg, min_height, min_width)
#                                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\batis\Documents\PROJETO-WISECONTROL\.venv_wisecontrol\Lib\site-packages\fast_plate_ocr\cli\validate_dataset.py", line 58, in _validate_dataset
#     with progress:
#   File "C:\Users\batis\Documents\PROJETO-WISECONTROL\.venv_wisecontrol\Lib\site-packages\rich\progress.py", line 1180, in __enter__
#     self.start()
#   File "C:\Users\batis\Documents\PROJETO-WISECONTROL\.venv_wisecontrol\Lib\site-packages\rich\progress.py", line 1171, in start
#     self.live.start(refresh=True)
#   File "C:\Users\batis\Documents\PROJETO-WISECONTROL\.venv_wisecontrol\Lib\site-packages\rich\live.py", line 139, in start
#     self.stop()
#   File "C:\Users\batis\Documents\PROJETO-WISECONTROL\.venv_wisecontrol\Lib\site-packages\rich\live.py", line 162, in stop
#     with self.console:
#   File "C:\Users\batis\Documents\PROJETO-WISECONTROL\.venv_wisecontrol\Lib\site-packages\rich\console.py", line 870, in __exit__
#     self._exit_buffer()
#   File "C:\Users\batis\Documents\PROJETO-WISECONTROL\.venv_wisecontrol\Lib\site-packages\rich\console.py", line 826, in _exit_buffer
#     self._check_buffer()
#   File "C:\Users\batis\Documents\PROJETO-WISECONTROL\.venv_wisecontrol\Lib\site-packages\rich\console.py", line 2038, in _check_buffer
#     self._write_buffer()
#   File "C:\Users\batis\Documents\PROJETO-WISECONTROL\.venv_wisecontrol\Lib\site-packages\rich\console.py", line 2074, in _write_buffer
#     legacy_windows_render(buffer, LegacyWindowsTerm(self.file))
#   File "C:\Users\batis\Documents\PROJETO-WISECONTROL\.venv_wisecontrol\Lib\site-packages\rich\_windows_renderer.py", line 17, in legacy_windows_render
#     term.write_styled(text, style)
#   File "C:\Users\batis\Documents\PROJETO-WISECONTROL\.venv_wisecontrol\Lib\site-packages\rich\_win32_console.py", line 441, in write_styled
#     self.write_text(text)
#   File "C:\Users\batis\Documents\PROJETO-WISECONTROL\.venv_wisecontrol\Lib\site-packages\rich\_win32_console.py", line 402, in write_text
#     self.write(text)
#   File "C:\Users\batis\AppData\Local\Programs\Python\Python312\Lib\encodings\cp1252.py", line 19, in encode
#     return codecs.charmap_encode(input,self.errors,encoding_table)[0]
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# UnicodeEncodeError: 'charmap' codec can't encode character '\u280b' in position 0: character maps to <undefined>

# %%
# Check the validation annotations
# !fast-plate-ocr validate-dataset \
  --annotations-file ./colombia_dataset/valid_annotations.csv \
  --plate-config-file cct_xs_v1_global_plate_config.yaml
