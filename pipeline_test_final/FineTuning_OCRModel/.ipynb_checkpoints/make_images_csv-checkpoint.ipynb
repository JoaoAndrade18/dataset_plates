# %%
import os
import pandas as pd
import cv2

# %%
images_path = "../RodoSol-ALPR/images"
infos_path = "../RodoSol-ALPR/split.txt"

# %%
df = pd.read_csv(infos_path, sep=';', header=None)
print(df.head())
# Out:
#                                  0         1
# 0  ./images/cars-br/img_000003.jpg  training
# 1  ./images/cars-br/img_000005.jpg  training
# 2  ./images/cars-br/img_000007.jpg  training
# 3  ./images/cars-br/img_000008.jpg  training
# 4  ./images/cars-br/img_000009.jpg  training

# %%
df_train = []
df_valid = []
df_test = []

for i, row in enumerate(df.iterrows()):
    if row[1][1] == "training":
        seps = row[1][0].split("/")
        if "motorcycles" in seps[2]:
            image = seps[3].split(".")[0]
            text_path = os.path.join(images_path, seps[2], image+".txt")
            df_plate = pd.read_csv(text_path, sep=':', header=None)
            plate = df_plate.iloc[1][1].strip()
            corners = df_plate.iloc[3][1].split(" ")[1:]
            df_train.append([row[1][0], plate, corners])

    if row[1][1] == "validation":
        seps = row[1][0].split("/")
        if "motorcycles" in seps[2]:
            image = seps[3].split(".")[0]
            text_path = os.path.join(images_path, seps[2], image+".txt")
            df_plate = pd.read_csv(text_path, sep=':', header=None)
            plate = df_plate.iloc[1][1].strip()
            corners = df_plate.iloc[3][1].split(" ")[1:]
            df_valid.append([row[1][0], plate, corners])

    if row[1][1] == "testing":
        seps = row[1][0].split("/")
        if "motorcycles" in seps[2]:
            image = seps[3].split(".")[0]
            text_path = os.path.join(images_path, seps[2], image+".txt")
            df_plate = pd.read_csv(text_path, sep=':', header=None)
            plate = df_plate.iloc[1][1].strip()
            corners = df_plate.iloc[3][1].split(" ")[1:]
            df_test.append([row[1][0], plate, corners]) 

print(df_train[0])  
print(df_valid[0])
# Out:
# ['./images/motorcycles-br/img_017505.jpg', 'MRW5561', ['498,1', '544,2', '542,38', '495,37']]
# ['./images/motorcycles-br/img_017502.jpg', 'QRC2267', ['593,132', '655,129', '656,182', '595,184']]

# %%
import pandas as pd
import os
from pathlib import Path

# Definir caminho para a pasta de treino e validacao
train_path = 'train/'
valid_path = 'valid/'
test_path = 'test/'

# Criar pastas de treino e validacao
Path(train_path).mkdir(parents=True, exist_ok=True)
Path(valid_path).mkdir(parents=True, exist_ok=True)
Path(test_path).mkdir(parents=True, exist_ok=True)

df_train = pd.DataFrame(df_train, columns=['image_path', 'plate_txt', 'bbox'])
df_valid = pd.DataFrame(df_valid, columns=['image_path', 'plate_txt', 'bbox'])
df_test = pd.DataFrame(df_test, columns=['image_path', 'plate_txt', 'bbox'])

# %%
csv = []
for idx, row in df_train.iterrows():
    img_path = Path(row['image_path'])
    plate_txt = row['plate_txt']
    bbox_list = row['bbox']

    img = cv2.imread("../RodoSol-ALPR/"+str(img_path))
    if img is None:
        print(f"[ERROR] {img}")
        continue

    points = [tuple(map(int, p.split(','))) for p in bbox_list]
    xs = [p[0] for p in points]
    ys = [p[1] for p in points]
    x_min, x_max = min(xs), max(xs)
    y_min, y_max = min(ys), max(ys)
    crop = img[y_min:y_max, x_min:x_max]

    new_name = img_path.stem + img_path.suffix  # ex: img_017505_plate.jpg
    train_path_com = os.path.join(train_path, new_name)
    cv2.imwrite(str(train_path_com), crop)

    csv.append({
        'image_path': os.path.join("train"+"/"+new_name),   # ex: "train/img_017505_plate.jpg"
        'plate_txt': plate_txt
    })

out_df = pd.DataFrame(csv, columns=['image_path', 'plate_txt'])
print(out_df)
out_df.to_csv('train.csv', index=False)
# Out:
#                 image_path plate_txt
# 0     train/img_017505.jpg   MRW5561
# 1     train/img_017506.jpg   OVL1662
# 2     train/img_017510.jpg   PPF2668
# 3     train/img_017512.jpg   OVJ2514
# 4     train/img_017513.jpg   PPJ4996
# ...                    ...       ...
# 3995  train/img_032491.jpg   MTZ7A41
# 3996  train/img_032492.jpg   QRF6E46
# 3997  train/img_032494.jpg   MTH1C91
# 3998  train/img_032496.jpg   KWU3F31
# 3999  train/img_032499.jpg   QPZ9B74
#
# [4000 rows x 2 columns]

# %%
csv = []
for idx, row in df_valid.iterrows():
    img_path = Path(row['image_path'])
    plate_txt = row['plate_txt']
    bbox_list = row['bbox']

    img = cv2.imread("../RodoSol-ALPR/"+str(img_path))
    if img is None:
        print(f"[ERROR] {img}")
        continue

    points = [tuple(map(int, p.split(','))) for p in bbox_list]
    xs = [p[0] for p in points]
    ys = [p[1] for p in points]
    x_min, x_max = min(xs), max(xs)
    y_min, y_max = min(ys), max(ys)
    crop = img[y_min:y_max, x_min:x_max]

    new_name = img_path.stem + img_path.suffix  # ex: img_017505_plate.jpg
    train_path_com = os.path.join(valid_path, new_name)
    cv2.imwrite(str(train_path_com), crop)

    csv.append({
        'image_path': os.path.join("valid"+"/"+new_name),   # ex: "train/img_017505_plate.jpg"
        'plate_txt': plate_txt
    })

out_df = pd.DataFrame(csv, columns=['image_path', 'plate_txt'])
print(out_df)
out_df.to_csv('valid.csv', index=False)
# Out:
#                 image_path plate_txt
# 0     valid/img_017502.jpg   QRC2267
# 1     valid/img_017503.jpg   PPX1174
# 2     valid/img_017507.jpg   MRS2786
# 3     valid/img_017511.jpg   ODO1487
# 4     valid/img_017514.jpg   QRB3067
# ...                    ...       ...
# 1995  valid/img_032482.jpg   QRI4J65
# 1996  valid/img_032488.jpg   MTF5A39
# 1997  valid/img_032493.jpg   MTR8I89
# 1998  valid/img_032495.jpg   QRG0C31
# 1999  valid/img_032500.jpg   MSU6E47
#
# [2000 rows x 2 columns]

# %%
csv = []
for idx, row in df_test.iterrows():
    img_path = Path(row['image_path'])
    plate_txt = row['plate_txt']
    bbox_list = row['bbox']

    img = cv2.imread("../RodoSol-ALPR/"+str(img_path))
    if img is None:
        print(f"[ERROR] {img}")
        continue

    points = [tuple(map(int, p.split(','))) for p in bbox_list]
    xs = [p[0] for p in points]
    ys = [p[1] for p in points]
    x_min, x_max = min(xs), max(xs)
    y_min, y_max = min(ys), max(ys)
    crop = img[y_min:y_max, x_min:x_max]

    new_name = img_path.stem + img_path.suffix  # ex: img_017505_plate.jpg
    test_path_com = os.path.join(test_path, new_name)
    cv2.imwrite(str(test_path_com), crop)

    csv.append({
        'image_path': os.path.join("test"+"/"+new_name),   # ex: "train/img_017505_plate.jpg"
        'plate_txt': plate_txt
    })

out_df = pd.DataFrame(csv, columns=['image_path', 'plate_txt'])
print(out_df)
out_df.to_csv('test.csv', index=False)
# Out:
#                image_path plate_txt
# 0     test/img_017501.jpg   MRH7545
# 1     test/img_017504.jpg   MSA2398
# 2     test/img_017508.jpg   MTU3834
# 3     test/img_017509.jpg   GZZ8751
# 4     test/img_017519.jpg   HNF9415
# ...                   ...       ...
# 3995  test/img_032487.jpg   QRJ7J46
# 3996  test/img_032489.jpg   PPW7J99
# 3997  test/img_032490.jpg   OYD5H74
# 3998  test/img_032497.jpg   QRE4I82
# 3999  test/img_032498.jpg   LRY7G97
#
# [4000 rows x 2 columns]
